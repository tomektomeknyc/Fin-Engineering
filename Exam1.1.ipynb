# %%
import pandas as pd

returns = pd.read_csv("data/Portfolios_Formed_on_ME_monthly_EW.csv", header= 0,index_col=0,parse_dates= True, 
                      na_values=-99.99)
returns
# Out:
#         <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  Lo 10  \
# 192607   NaN  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33  -1.45
# 192608   NaN   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33   5.12
# 192609   NaN  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09   0.93
# 192610   NaN  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95  -4.84
# 192611   NaN  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16  -0.78
# ...      ...    ...     ...    ...    ...    ...    ...    ...    ...    ...
# 201808   NaN   3.47    4.04   2.87   3.09   5.05   3.90   3.54   2.49   2.41
# 201809   NaN  -2.24   -1.85   0.08  -2.04  -2.38  -2.48  -0.74   0.19  -1.68
# 201810   NaN -10.76  -10.88  -7.63 -10.52 -11.74 -10.55  -9.45  -7.41 -10.02
# 201811   NaN  -2.08    2.18   2.19  -2.78   1.69   1.46   2.62   2.49  -3.65
# 201812   NaN -14.28  -12.41  -9.76 -14.77 -12.44 -12.22 -11.34  -9.21 -15.31
#
# ...

# %%
columns=['Lo 20', 'Hi 20']
returns = returns[columns]
returns.head()
# Out:
#         Lo 20  Hi 20
# 192607  -0.57   3.33
# 192608   3.84   2.33
# 192609  -0.48  -0.09
# 192610  -3.29  -2.95
# 192611  -0.55   3.16

# %%
returns
# Out:
#         Lo 20  Hi 20
# 192607  -0.57   3.33
# 192608   3.84   2.33
# 192609  -0.48  -0.09
# 192610  -3.29  -2.95
# 192611  -0.55   3.16
# ...       ...    ...
# 201808   3.09   2.49
# 201809  -2.04   0.19
# 201810 -10.52  -7.41
# 201811  -2.78   2.49
# 201812 -14.77  -9.21
#
# [1110 rows x 2 columns]

# %%
returns.std()
# Out:
# Lo 20    9.719729
# Hi 20    5.632515
# dtype: float64

# %%
returns= returns.loc['1999-01':'2016-12']
returns
# Out:
#         Lo 20  Hi 20
# 199901  11.14   1.53
# 199902  -3.99  -1.72
# 199903  -3.08   3.68
# 199904   8.24   6.79
# 199905   4.35  -0.48
# ...       ...    ...
# 201508  -3.47  -5.59
# 201509  -6.10  -3.33
# 201510   3.85   7.10
# 201511   1.65   0.15
# 201512  -5.00  -2.29
#
# [204 rows x 2 columns]

# %%
n_months = returns.shape[0]
n_months
# Out:
# 204

# %%
import numpy as np
annualized_return = (returns+1).prod()**(12/n_months)-1
annualized_return
# Out:
# Lo 20   NaN
# Hi 20   NaN
# dtype: float64

# %%
returns = returns/100

# %%
returns
# Out:
#          Lo 20   Hi 20
# 199901  0.1114  0.0153
# 199902 -0.0399 -0.0172
# 199903 -0.0308  0.0368
# 199904  0.0824  0.0679
# 199905  0.0435 -0.0048
# ...        ...     ...
# 201508 -0.0347 -0.0559
# 201509 -0.0610 -0.0333
# 201510  0.0385  0.0710
# 201511  0.0165  0.0015
# 201512 -0.0500 -0.0229
#
# [204 rows x 2 columns]

# %%
import numpy as np
annualized_return = (returns+1).prod()**(12/n_months)-1
annualized_return
# Out:
# Lo 20    0.114426
# Hi 20    0.062865
# dtype: float64

# %%
returns
# Out:
#          Lo 20   Hi 20
# 199901  0.1114  0.0153
# 199902 -0.0399 -0.0172
# 199903 -0.0308  0.0368
# 199904  0.0824  0.0679
# 199905  0.0435 -0.0048
# ...        ...     ...
# 201508 -0.0347 -0.0559
# 201509 -0.0610 -0.0333
# 201510  0.0385  0.0710
# 201511  0.0165  0.0015
# 201512 -0.0500 -0.0229
#
# [204 rows x 2 columns]

# %%
returns.plot.line()

# %%
returns.index
# Out:
# Int64Index([199901, 199902, 199903, 199904, 199905, 199906, 199907, 199908,
#             199909, 199910,
#             ...
#             201503, 201504, 201505, 201506, 201507, 201508, 201509, 201510,
#             201511, 201512],
#            dtype='int64', length=204)

# %%
returns.index = pd.to_datetime(returns.index, format="%Y%m")
returns.head()
# Out:
#              Lo 20   Hi 20
# 1999-01-01  0.1114  0.0153
# 1999-02-01 -0.0399 -0.0172
# 1999-03-01 -0.0308  0.0368
# 1999-04-01  0.0824  0.0679
# 1999-05-01  0.0435 -0.0048

# %%
returns
# Out:
#              Lo 20   Hi 20
# 1999-01-01  0.1114  0.0153
# 1999-02-01 -0.0399 -0.0172
# 1999-03-01 -0.0308  0.0368
# 1999-04-01  0.0824  0.0679
# 1999-05-01  0.0435 -0.0048
# ...            ...     ...
# 2015-08-01 -0.0347 -0.0559
# 2015-09-01 -0.0610 -0.0333
# 2015-10-01  0.0385  0.0710
# 2015-11-01  0.0165  0.0015
# 2015-12-01 -0.0500 -0.0229
#
# [204 rows x 2 columns]

# %%
returns.index
# Out:
# DatetimeIndex(['1999-01-01', '1999-02-01', '1999-03-01', '1999-04-01',
#                '1999-05-01', '1999-06-01', '1999-07-01', '1999-08-01',
#                '1999-09-01', '1999-10-01',
#                ...
#                '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01',
#                '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01',
#                '2015-11-01', '2015-12-01'],
#               dtype='datetime64[ns]', length=204, freq=None)

# %% [markdown]
# Compute Drawdown
# -Wealth Index
# -Previous Peaks
# -Drawdown as a percentage of the previous peak

# %%
wealth_index = 1000*(1+ returns["Hi 20"]).cumprod()

# %%
wealth_index.head()
# Out:
# 1999-01-01    1015.300000
# 1999-02-01     997.836840
# 1999-03-01    1034.557236
# 1999-04-01    1104.803672
# 1999-05-01    1099.500614
# Name: Hi 20, dtype: float64

# %%
wealth_index.plot.line()

# %%
previous_peaks = wealth_index.cummax()

# %%
previous_peaks.plot()

# %%
drawdown= (wealth_index - previous_peaks)/previous_peaks
drawdown.plot()

# %%
drawdown.min()
# Out:
# -0.5527349978713653

# %%
drawdown.max()
# Out:
# 0.0

# %%
wealth_index = 1000*(1+ returns["Lo 20"]).cumprod()
wealth_index.head()
# Out:
# 1999-01-01    1111.400000
# 1999-02-01    1067.055140
# 1999-03-01    1034.189842
# 1999-04-01    1119.407085
# 1999-05-01    1168.101293
# Name: Lo 20, dtype: float64

# %%
wealth_index.plot.line()

# %%
previous_peaks = wealth_index.cummax()
previous_peaks.plot()

# %%
drawdown= (wealth_index - previous_peaks)/previous_peaks
drawdown.plot()

# %%
drawdown.min()
# Out:
# -0.6248092431236988

# %%
drawdown.max()
# Out:
# 0.0

# %%
wealth_index
# Out:
# 1999-01-01    1111.400000
# 1999-02-01    1067.055140
# 1999-03-01    1034.189842
# 1999-04-01    1119.407085
# 1999-05-01    1168.101293
#                  ...
# 2015-08-01    6698.386200
# 2015-09-01    6289.784642
# 2015-10-01    6531.941351
# 2015-11-01    6639.718383
# 2015-12-01    6307.732464
# Name: Lo 20, Length: 204, dtype: float64

# %%
drawdown["1975":].idxmin()
# Out:
# Timestamp('2009-02-01 00:00:00')

# %%
returns
# Out:
#              Lo 20   Hi 20
# 1999-01-01  0.1114  0.0153
# 1999-02-01 -0.0399 -0.0172
# 1999-03-01 -0.0308  0.0368
# 1999-04-01  0.0824  0.0679
# 1999-05-01  0.0435 -0.0048
# ...            ...     ...
# 2015-08-01 -0.0347 -0.0559
# 2015-09-01 -0.0610 -0.0333
# 2015-10-01  0.0385  0.0710
# 2015-11-01  0.0165  0.0015
# 2015-12-01 -0.0500 -0.0229
#
# [204 rows x 2 columns]

# %%
wealth_index = 1000*(1+ returns["Lo 20"]).cumprod()

# %%
wealth_index.head()
# Out:
# 1999-01-01    1111.400000
# 1999-02-01    1067.055140
# 1999-03-01    1034.189842
# 1999-04-01    1119.407085
# 1999-05-01    1168.101293
# Name: Lo 20, dtype: float64

# %%
wealth_index.plot.line()

# %%
previous_peaks = wealth_index.cummax()

# %%
previous_peaks.plot()

# %%
drawdown =(wealth_index - previous_peaks)/previous_peaks
drawdown.plot()

# %%
drawdown.head()
# Out:
# 1999-01-01    0.000000
# 1999-02-01   -0.039900
# 1999-03-01   -0.069471
# 1999-04-01    0.000000
# 1999-05-01    0.000000
# Name: Lo 20, dtype: float64

# %%
drawdown.min()
# Out:
# -0.6248092431236988

# %%
drawdown["1999":].idxmin()
# Out:
# Timestamp('2009-02-01 00:00:00')

# %%
returns
# Out:
#              Lo 20   Hi 20
# 1999-01-01  0.1114  0.0153
# 1999-02-01 -0.0399 -0.0172
# 1999-03-01 -0.0308  0.0368
# 1999-04-01  0.0824  0.0679
# 1999-05-01  0.0435 -0.0048
# ...            ...     ...
# 2015-08-01 -0.0347 -0.0559
# 2015-09-01 -0.0610 -0.0333
# 2015-10-01  0.0385  0.0710
# 2015-11-01  0.0165  0.0015
# 2015-12-01 -0.0500 -0.0229
#
# [204 rows x 2 columns]

# %%
wealth_index = 1000*(1+ returns["Hi 20"]).cumprod()

# %%
wealth_index
# Out:
# 1999-01-01    1015.300000
# 1999-02-01     997.836840
# 1999-03-01    1034.557236
# 1999-04-01    1104.803672
# 1999-05-01    1099.500614
#                  ...
# 2015-08-01    2782.642979
# 2015-09-01    2689.980968
# 2015-10-01    2880.969617
# 2015-11-01    2885.291071
# 2015-12-01    2819.217906
# Name: Hi 20, Length: 204, dtype: float64

# %%
wealth_index.plot.line()

# %%
previous_peaks = wealth_index.cummax()

# %%
previous_peaks.plot()

# %%
drawdown =(wealth_index - previous_peaks)/previous_peaks
drawdown.plot()

# %%
drawdown.head()
# Out:
# 1999-01-01    0.0000
# 1999-02-01   -0.0172
# 1999-03-01    0.0000
# 1999-04-01    0.0000
# 1999-05-01   -0.0048
# Name: Hi 20, dtype: float64

# %%
drawdown.min()
# Out:
# -0.5527349978713653

# %%
drawdown["1999":].idxmin()
# Out:
# Timestamp('2009-02-01 00:00:00')

# %%
import pandas as pd

returns = pd.read_csv("data/edhec-hedgefundindices.csv", header= 0,index_col=0,parse_dates= True, 
                      na_values=-99.99)
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 1997-01-31                   1.19        3.93                   1.78
# 1997-02-28                   1.23        2.98                   1.22
# 1997-03-31                   0.78       -0.21                  -0.12
# 1997-04-30                   0.86       -1.70                   0.30
# 1997-05-31                   1.56       -0.15                   2.33
# ...                           ...         ...                    ...
# 2018-07-31                   0.21       -0.58                   0.93
# 2018-08-31                   0.24        1.66                   0.02
# 2018-09-30                   0.34       -0.54                   0.50
# 2018-10-31                  -0.73       -3.14                  -1.58
# 2018-11-30                  -0.68       -0.53                  -1.93
#
#             Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# ...

# %%
returns = returns.loc["2009":"2018"]
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2009-01-31                   4.91       -0.16                   0.82
# 2009-02-28                   1.64       -0.31                  -1.22
# 2009-03-31                   2.35       -1.80                   0.22
# 2009-04-30                   5.00       -1.40                   3.87
# 2009-05-31                   5.78        2.13                   5.04
# ...                           ...         ...                    ...
# 2018-07-31                   0.21       -0.58                   0.93
# 2018-08-31                   0.24        1.66                   0.02
# 2018-09-30                   0.34       -0.54                   0.50
# 2018-10-31                  -0.73       -3.14                  -1.58
# 2018-11-30                  -0.68       -0.53                  -1.93
#
#             Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# ...

# %% [markdown]
# SemiDeviation

# %%
import pandas as pd
import edhec_risk_kit as erk
hfi = erk.get_hfi_returns()
erk.semideviation(hfi)
# Out:
# Convertible Arbitrage     0.019540
# CTA Global                0.012443
# Distressed Securities     0.015185
# Emerging Markets          0.028039
# Equity Market Neutral     0.009566
# Event Driven              0.015429
# Fixed Income Arbitrage    0.017763
# Global Macro              0.006579
# Long/Short Equity         0.014051
# Merger Arbitrage          0.008875
# Relative Value            0.012244
# Short Selling             0.027283
# Funds Of Funds            0.012122
# dtype: float64

# %%
hfi.std(ddof=0)
# Out:
# Convertible Arbitrage     0.016536
# CTA Global                0.023290
# Distressed Securities     0.017009
# Emerging Markets          0.032476
# Equity Market Neutral     0.008115
# Event Driven              0.016712
# Fixed Income Arbitrage    0.011517
# Global Macro              0.014694
# Long/Short Equity         0.019897
# Merger Arbitrage          0.009600
# Relative Value            0.011462
# Short Selling             0.047655
# Funds Of Funds            0.015536
# dtype: float64

# %%
hfi[hfi<0].std(ddof=0)
# Out:
# Convertible Arbitrage     0.019540
# CTA Global                0.012443
# Distressed Securities     0.015185
# Emerging Markets          0.028039
# Equity Market Neutral     0.009566
# Event Driven              0.015429
# Fixed Income Arbitrage    0.017763
# Global Macro              0.006579
# Long/Short Equity         0.014051
# Merger Arbitrage          0.008875
# Relative Value            0.012244
# Short Selling             0.027283
# Funds Of Funds            0.012122
# dtype: float64

# %%
erk.semidiviation(hfi)
# Out:
# Convertible Arbitrage     0.019540
# CTA Global                0.012443
# Distressed Securities     0.015185
# Emerging Markets          0.028039
# Equity Market Neutral     0.009566
# Event Driven              0.015429
# Fixed Income Arbitrage    0.017763
# Global Macro              0.006579
# Long/Short Equity         0.014051
# Merger Arbitrage          0.008875
# Relative Value            0.012244
# Short Selling             0.027283
# Funds Of Funds            0.012122
# dtype: float64

# %% [markdown]
# ### Semideviation

# %%
import pandas as pd
import edhec_risk_kit as erk
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
hfi = erk.get_hfi_returns()

# %%
hfi.std(ddof = 0)
# Out:
# Convertible Arbitrage     0.016536
# CTA Global                0.023290
# Distressed Securities     0.017009
# Emerging Markets          0.032476
# Equity Market Neutral     0.008115
# Event Driven              0.016712
# Fixed Income Arbitrage    0.011517
# Global Macro              0.014694
# Long/Short Equity         0.019897
# Merger Arbitrage          0.009600
# Relative Value            0.011462
# Short Selling             0.047655
# Funds Of Funds            0.015536
# dtype: float64

# %%
hfi[hfi<0].std(ddof=0)
# Out:
# Convertible Arbitrage     0.019540
# CTA Global                0.012443
# Distressed Securities     0.015185
# Emerging Markets          0.028039
# Equity Market Neutral     0.009566
# Event Driven              0.015429
# Fixed Income Arbitrage    0.017763
# Global Macro              0.006579
# Long/Short Equity         0.014051
# Merger Arbitrage          0.008875
# Relative Value            0.012244
# Short Selling             0.027283
# Funds Of Funds            0.012122
# dtype: float64

# %%
erk.semideviation(hfi)
# Out:
# Convertible Arbitrage     0.019540
# CTA Global                0.012443
# Distressed Securities     0.015185
# Emerging Markets          0.028039
# Equity Market Neutral     0.009566
# Event Driven              0.015429
# Fixed Income Arbitrage    0.017763
# Global Macro              0.006579
# Long/Short Equity         0.014051
# Merger Arbitrage          0.008875
# Relative Value            0.012244
# Short Selling             0.027283
# Funds Of Funds            0.012122
# dtype: float64

# %%
import pandas as pd

returns = pd.read_csv("data/edhec-hedgefundindices.csv", header= 0,index_col=0,parse_dates= True, 
                      na_values=-99.99)
returns = returns.loc["2009":"2018"]
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2009-01-31                   4.91       -0.16                   0.82
# 2009-02-28                   1.64       -0.31                  -1.22
# 2009-03-31                   2.35       -1.80                   0.22
# 2009-04-30                   5.00       -1.40                   3.87
# 2009-05-31                   5.78        2.13                   5.04
# ...                           ...         ...                    ...
# 2018-07-31                   0.21       -0.58                   0.93
# 2018-08-31                   0.24        1.66                   0.02
# 2018-09-30                   0.34       -0.54                   0.50
# 2018-10-31                  -0.73       -3.14                  -1.58
# 2018-11-30                  -0.68       -0.53                  -1.93
#
#             Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# ...

# %%
erk.semideviation(returns)
# Out:
# Convertible Arbitrage     0.668103
# CTA Global                1.099578
# Distressed Securities     0.949845
# Emerging Markets          1.527598
# Equity Market Neutral     0.518610
# Event Driven              1.013464
# Fixed Income Arbitrage    0.332054
# Global Macro              0.507508
# Long/Short Equity         1.213857
# Merger Arbitrage          0.361121
# Relative Value            0.571123
# Short Selling             2.124006
# Funds Of Funds            0.794842
# dtype: float64

# %%
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2009-01-31                   4.91       -0.16                   0.82
# 2009-02-28                   1.64       -0.31                  -1.22
# 2009-03-31                   2.35       -1.80                   0.22
# 2009-04-30                   5.00       -1.40                   3.87
# 2009-05-31                   5.78        2.13                   5.04
# ...                           ...         ...                    ...
# 2018-07-31                   0.21       -0.58                   0.93
# 2018-08-31                   0.24        1.66                   0.02
# 2018-09-30                   0.34       -0.54                   0.50
# 2018-10-31                  -0.73       -3.14                  -1.58
# 2018-11-30                  -0.68       -0.53                  -1.93
#
#             Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# ...

# %%
import pandas as pd

returns = pd.read_csv("data/edhec-hedgefundindices.csv", header= 0,index_col=0,parse_dates= True, 
                      na_values=-99.99)
returns = returns.loc["2009"]
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2009-01-31                   4.91       -0.16                   0.82
# 2009-02-28                   1.64       -0.31                  -1.22
# 2009-03-31                   2.35       -1.80                   0.22
# 2009-04-30                   5.00       -1.40                   3.87
# 2009-05-31                   5.78        2.13                   5.04
# 2009-06-30                   2.41       -1.47                   1.98
# 2009-07-31                   6.11       -0.12                   3.11
# 2009-08-31                   3.15        0.54                   2.44
# 2009-09-30                   3.68        1.51                   4.10
# 2009-10-31                   1.19       -1.47                   1.39
# 2009-11-30                   0.80        3.32                   2.02
# 2009-12-31                   2.15       -2.53                   3.24
#
# ...

# %%
erk.semideviation(returns)
# Out:
# Convertible Arbitrage          NaN
# CTA Global                0.817034
# Distressed Securities     0.000000
# Emerging Markets          0.105000
# Equity Market Neutral     0.179072
# Event Driven              0.000000
# Fixed Income Arbitrage         NaN
# Global Macro              0.271972
# Long/Short Equity         0.588048
# Merger Arbitrage               NaN
# Relative Value            0.000000
# Short Selling             2.229405
# Funds Of Funds            0.080000
# dtype: float64

# %%
hfi[hfi<0].std(ddof=0)
# Out:
# Convertible Arbitrage     0.019540
# CTA Global                0.012443
# Distressed Securities     0.015185
# Emerging Markets          0.028039
# Equity Market Neutral     0.009566
# Event Driven              0.015429
# Fixed Income Arbitrage    0.017763
# Global Macro              0.006579
# Long/Short Equity         0.014051
# Merger Arbitrage          0.008875
# Relative Value            0.012244
# Short Selling             0.027283
# Funds Of Funds            0.012122
# dtype: float64

# %%
erk.semideviation(returns).sort_values()
# Out:
# Global Macro              0.628980
# Merger Arbitrage          0.637465
# Equity Market Neutral     0.965100
# Funds Of Funds            1.129540
# Relative Value            1.199383
# CTA Global                1.228228
# Event Driven              1.307366
# Distressed Securities     1.327947
# Long/Short Equity         1.364032
# Fixed Income Arbitrage    1.517811
# Convertible Arbitrage     1.988740
# Emerging Markets          2.166384
# Short Selling             2.490719
# dtype: float64

# %%
hfi[hfi<0].std(ddof=0)
# Out:
# Convertible Arbitrage     0.019540
# CTA Global                0.012443
# Distressed Securities     0.015185
# Emerging Markets          0.028039
# Equity Market Neutral     0.009566
# Event Driven              0.015429
# Fixed Income Arbitrage    0.017763
# Global Macro              0.006579
# Long/Short Equity         0.014051
# Merger Arbitrage          0.008875
# Relative Value            0.012244
# Short Selling             0.027283
# Funds Of Funds            0.012122
# dtype: float64

# %%
import pandas as pd
import edhec_risk_kit as erk
hfi = erk.get_hfi_returns()

# %%
import pandas as pd
import edhec_risk_kit as erk
hfi = erk.get_hfi_returns()
erk.semideviation(hfi)
# Out:
# Convertible Arbitrage     0.019540
# CTA Global                0.012443
# Distressed Securities     0.015185
# Emerging Markets          0.028039
# Equity Market Neutral     0.009566
# Event Driven              0.015429
# Fixed Income Arbitrage    0.017763
# Global Macro              0.006579
# Long/Short Equity         0.014051
# Merger Arbitrage          0.008875
# Relative Value            0.012244
# Short Selling             0.027283
# Funds Of Funds            0.012122
# dtype: float64

# %%
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2009-01-31                   4.91       -0.16                   0.82
# 2009-02-28                   1.64       -0.31                  -1.22
# 2009-03-31                   2.35       -1.80                   0.22
# 2009-04-30                   5.00       -1.40                   3.87
# 2009-05-31                   5.78        2.13                   5.04
# 2009-06-30                   2.41       -1.47                   1.98
# 2009-07-31                   6.11       -0.12                   3.11
# 2009-08-31                   3.15        0.54                   2.44
# 2009-09-30                   3.68        1.51                   4.10
# 2009-10-31                   1.19       -1.47                   1.39
# 2009-11-30                   0.80        3.32                   2.02
# 2009-12-31                   2.15       -2.53                   3.24
#
# ...

# %%
erk.semideviation(returns)
# Out:
# Convertible Arbitrage          NaN
# CTA Global                0.817034
# Distressed Securities     0.000000
# Emerging Markets          0.105000
# Equity Market Neutral     0.179072
# Event Driven              0.000000
# Fixed Income Arbitrage         NaN
# Global Macro              0.271972
# Long/Short Equity         0.588048
# Merger Arbitrage               NaN
# Relative Value            0.000000
# Short Selling             2.229405
# Funds Of Funds            0.080000
# dtype: float64

# %% [markdown]
# $$ S(R) = \frac{E[(R-E(R))^3]}{\sigma_R^3} $$
# ### Skewness

# %%
erk.skewness(returns).sort_values()
# Out:
# Merger Arbitrage         -0.775489
# Distressed Securities    -0.338054
# Event Driven             -0.167137
# Short Selling            -0.002675
# Long/Short Equity         0.102470
# Equity Market Neutral     0.243892
# Convertible Arbitrage     0.283469
# Emerging Markets          0.484748
# Fixed Income Arbitrage    0.495498
# Relative Value            0.536463
# CTA Global                0.590052
# Global Macro              0.647263
# Funds Of Funds            0.956387
# dtype: float64

# %%
erk.kurtosis(returns).sort_values()
# Out:
# Convertible Arbitrage     1.718582
# Fixed Income Arbitrage    1.922419
# Short Selling             2.013333
# Long/Short Equity         2.325368
# Emerging Markets          2.329596
# CTA Global                2.369934
# Relative Value            2.383865
# Distressed Securities     2.472150
# Merger Arbitrage          2.553070
# Global Macro              2.565275
# Event Driven              2.605620
# Equity Market Neutral     2.630301
# Funds Of Funds            3.659997
# dtype: float64

# %%
import pandas as pd

returns = pd.read_csv("data/edhec-hedgefundindices.csv", header= 0,index_col=0,parse_dates= True, 
                      na_values=-99.99)
returns = returns.loc["2000":"2018"]
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2000-01-31                   2.27        1.28                   0.88
# 2000-02-29                   2.67       -0.22                   4.21
# 2000-03-31                   2.43       -1.38                   1.03
# 2000-04-30                   2.23       -2.41                  -1.01
# 2000-05-31                   1.49        1.14                  -1.32
# ...                           ...         ...                    ...
# 2018-07-31                   0.21       -0.58                   0.93
# 2018-08-31                   0.24        1.66                   0.02
# 2018-09-30                   0.34       -0.54                   0.50
# 2018-10-31                  -0.73       -3.14                  -1.58
# 2018-11-30                  -0.68       -0.53                  -1.93
#
#             Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# ...

# %%
erk.kurtosis(returns).sort_values()
# Out:
# CTA Global                 2.845022
# Global Macro               3.653278
# Short Selling              4.352758
# Long/Short Equity          4.472589
# Merger Arbitrage           4.520785
# Event Driven               5.543444
# Emerging Markets           5.941289
# Distressed Securities      6.231720
# Funds Of Funds             7.584725
# Relative Value            12.731096
# Equity Market Neutral     20.329621
# Convertible Arbitrage     23.001449
# Fixed Income Arbitrage    33.378729
# dtype: float64

# %%
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2000-01-31                   2.27        1.28                   0.88
# 2000-02-29                   2.67       -0.22                   4.21
# 2000-03-31                   2.43       -1.38                   1.03
# 2000-04-30                   2.23       -2.41                  -1.01
# 2000-05-31                   1.49        1.14                  -1.32
# ...                           ...         ...                    ...
# 2018-07-31                   0.21       -0.58                   0.93
# 2018-08-31                   0.24        1.66                   0.02
# 2018-09-30                   0.34       -0.54                   0.50
# 2018-10-31                  -0.73       -3.14                  -1.58
# 2018-11-30                  -0.68       -0.53                  -1.93
#
#             Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# ...

# %%
import pandas as pd

returns = pd.read_csv("data/edhec-hedgefundindices.csv", header= 0,index_col=0,parse_dates= True, 
                      na_values=-99.99)
returns = returns.loc["2009"]
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2009-01-31                   4.91       -0.16                   0.82
# 2009-02-28                   1.64       -0.31                  -1.22
# 2009-03-31                   2.35       -1.80                   0.22
# 2009-04-30                   5.00       -1.40                   3.87
# 2009-05-31                   5.78        2.13                   5.04
# 2009-06-30                   2.41       -1.47                   1.98
# 2009-07-31                   6.11       -0.12                   3.11
# 2009-08-31                   3.15        0.54                   2.44
# 2009-09-30                   3.68        1.51                   4.10
# 2009-10-31                   1.19       -1.47                   1.39
# 2009-11-30                   0.80        3.32                   2.02
# 2009-12-31                   2.15       -2.53                   3.24
#
# ...

# %%
erk.skewness(returns).sort_values()
# Out:
# Merger Arbitrage         -0.775489
# Distressed Securities    -0.338054
# Event Driven             -0.167137
# Short Selling            -0.002675
# Long/Short Equity         0.102470
# Equity Market Neutral     0.243892
# Convertible Arbitrage     0.283469
# Emerging Markets          0.484748
# Fixed Income Arbitrage    0.495498
# Relative Value            0.536463
# CTA Global                0.590052
# Global Macro              0.647263
# Funds Of Funds            0.956387
# dtype: float64

# %%
returns
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2009-01-31                   4.91       -0.16                   0.82
# 2009-02-28                   1.64       -0.31                  -1.22
# 2009-03-31                   2.35       -1.80                   0.22
# 2009-04-30                   5.00       -1.40                   3.87
# 2009-05-31                   5.78        2.13                   5.04
# 2009-06-30                   2.41       -1.47                   1.98
# 2009-07-31                   6.11       -0.12                   3.11
# 2009-08-31                   3.15        0.54                   2.44
# 2009-09-30                   3.68        1.51                   4.10
# 2009-10-31                   1.19       -1.47                   1.39
# 2009-11-30                   0.80        3.32                   2.02
# 2009-12-31                   2.15       -2.53                   3.24
#
# ...

# %%
erk.semideviation(returns).sort_values()
# Out:
# Distressed Securities     0.000000
# Event Driven              0.000000
# Relative Value            0.000000
# Funds Of Funds            0.080000
# Emerging Markets          0.105000
# Equity Market Neutral     0.179072
# Global Macro              0.271972
# Long/Short Equity         0.588048
# CTA Global                0.817034
# Short Selling             2.229405
# Convertible Arbitrage          NaN
# Fixed Income Arbitrage         NaN
# Merger Arbitrage               NaN
# dtype: float64
